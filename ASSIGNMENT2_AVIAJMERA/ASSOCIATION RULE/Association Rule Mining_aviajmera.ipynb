# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### Installing Pycaret and Importing needed libraries

# %%
 # !pip install pycaret==3.0.0.rc1

# %%
import pandas as pd

# %% [markdown]
# ## Importing dataset

# %%
dataset = pd.read_csv('/content/zz.csv', delimiter=';')
# Out:
# <ipython-input-4-14a1b48e7d5c>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('/content/zz.csv', delimiter=';')

# %% [markdown]
# ## Data Description

# %%
dataset.shape
# Out:
# (522064, 7)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB

# %%
dataset.describe(include='all')
# Out:
#           BillNo                            Itemname       Quantity  \
# count   522064.0                              520609  522064.000000
# unique   21665.0                                4185            NaN
# top     573585.0  WHITE HANGING HEART T-LIGHT HOLDER            NaN
# freq      1114.0                                2269            NaN
# mean         NaN                                 NaN      10.090435
# std          NaN                                 NaN     161.110525
# min          NaN                                 NaN   -9600.000000
# 25%          NaN                                 NaN       1.000000
# 50%          NaN                                 NaN       3.000000
# 75%          NaN                                 NaN      10.000000
# max          NaN                                 NaN   80995.000000
#
#                     Date   Price     CustomerID         Country
# count             522064  522064  388023.000000          522064
# ...

# %%
dataset.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %% [markdown]
# ## **Pycaret Setup**

# %%
from pycaret.arules import *

# %% [markdown]
# ## Creating Model

# %%
arule = setup(data = dataset,
                    transaction_id = 'BillNo',
                    item_id = 'Itemname')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c602f" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_c602f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c602f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c602f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_c602f_row0_col1" class="data row0 col1" >6021</td>
#     </tr>
#     <tr>
#       <td id="T_c602f_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_c602f_row1_col1" class="data row1 col1" >21665</td>
#     </tr>
#     <tr>
#       <td id="T_c602f_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_c602f_row2_col1" class="data row2 col1" >4186</td>
#     </tr>
#     <tr>
#       <td id="T_c602f_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_c602f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# ...

# %% [markdown]
# ## **Analyze Model**

# %%
model1 = create_model()

# %%
print(model1.shape)
# Out:
# (0, 10)

# %%
model1.head()
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %%
a
