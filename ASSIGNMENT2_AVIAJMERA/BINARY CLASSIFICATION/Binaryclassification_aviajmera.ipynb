# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Installing Pycaret and Importing needed libraries

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 44.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 49.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %% [markdown]
# ## Importing dataset

# %%
dataset = pd.read_csv('/content/diabetes.csv')

# %% [markdown]
# ## Data Description

# %%
dataset.shape

# %%
dataset.info()

# %%
dataset.describe(include='all')

# %% [markdown]
# ## **Pycaret Setup**

# %%
from pycaret.classification import *
pycaret_setup = setup(data = dataset, target = 'Outcome', session_id=123)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-9d7809b077ff> in <cell line: 1>()
# ----> 1 from pycaret.classification import *
#       2 pycaret_setup = setup(data = dataset, target = 'Outcome', session_id=123)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/__init__.py in <module>
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#
# /usr/local/lib/python3.10/dist-packages/pycaret/classification/functional.py in <module>
#       6 from joblib.memory import Memory
#       7
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# ...

# %% [markdown]
# ## Compare Models

# %%
best=compare_models()

# %%
best

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'feature')

# %%
mymodel = create_model(best)

# %%
mymodel = tune_model(mymodel)

# %%
mymodel = finalize_model(mymodel)

# %%
save_model(mymodel,'BinaryClassificat')

# %%
load_model('BinaryClassificat')
